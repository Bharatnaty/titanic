# %%
import pandas as pd
train=pd.read_csv(r"C:\Users\Kishore\Desktop\titanic\train.csv")
test=pd.read_csv(r"C:\Users\Kishore\Desktop\titanic\test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Chapman, Mr. John Henry  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
test.describe(include="all")
# Out:
#         PassengerId      Pclass                Name   Sex         Age  \
# count    418.000000  418.000000                 418   418  332.000000
# unique          NaN         NaN                 418     2         NaN
# top             NaN         NaN  Storey, Mr. Thomas  male         NaN
# freq            NaN         NaN                   1   266         NaN
# mean    1100.500000    2.265550                 NaN   NaN   30.272590
# std      120.810458    0.841838                 NaN   NaN   14.181209
# min      892.000000    1.000000                 NaN   NaN    0.170000
# 25%      996.250000    1.000000                 NaN   NaN   21.000000
# 50%     1100.500000    3.000000                 NaN   NaN   27.000000
# 75%     1204.750000    3.000000                 NaN   NaN   39.000000
# max     1309.000000    3.000000                 NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# ...

# %%
train.drop(["Cabin"],axis=1,inplace=True)

# %%
test.drop(["Cabin"],axis=1,inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
train["Age"].fillna(train["Age"].mean(),inplace=True)

# %%
train["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
test["Age"].fillna(test["Age"].mean(),inplace=True)

# %%
test["Age"]
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
train.drop(["Name"],axis=1,inplace=True)

# %%
train.drop(["Ticket"],axis=1,inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
test.drop(["Name","Ticket"],axis=1,inplace=True)

# %%
test
# Out:
#      PassengerId  Pclass     Sex       Age  SibSp  Parch      Fare Embarked
# 0            892       3    male  34.50000      0      0    7.8292        Q
# 1            893       3  female  47.00000      1      0    7.0000        S
# 2            894       2    male  62.00000      0      0    9.6875        Q
# 3            895       3    male  27.00000      0      0    8.6625        S
# 4            896       3  female  22.00000      1      1   12.2875        S
# ..           ...     ...     ...       ...    ...    ...       ...      ...
# 413         1305       3    male  30.27259      0      0    8.0500        S
# 414         1306       1  female  39.00000      0      0  108.9000        C
# 415         1307       3    male  38.50000      0      0    7.2500        S
# 416         1308       3    male  30.27259      0      0    8.0500        S
# 417         1309       3    male  30.27259      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
dummy=pd.get_dummies(train["Sex"],drop_first=True)

# %%
train=pd.concat([dummy,train],axis=1)

# %%
train
# Out:
#      male  PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0       1            1         0       3    male  22.000000      1      0
# 1       0            2         1       1  female  38.000000      1      0
# 2       0            3         1       3  female  26.000000      0      0
# 3       0            4         1       1  female  35.000000      1      0
# 4       1            5         0       3    male  35.000000      0      0
# ..    ...          ...       ...     ...     ...        ...    ...    ...
# 886     1          887         0       2    male  27.000000      0      0
# 887     0          888         1       1  female  19.000000      0      0
# 888     0          889         0       3  female  29.699118      1      2
# 889     1          890         1       1    male  26.000000      0      0
# 890     1          891         0       3    male  32.000000      0      0
#
#         Fare Embarked
# 0     7.2500        S
# 1    71.2833        C
# ...

# %%
dummy1=pd.get_dummies(test["Sex"],drop_first=True)

# %%
test=pd.concat([test,dummy1],axis=1)

# %%
test
# Out:
#      PassengerId  Pclass     Sex       Age  SibSp  Parch      Fare Embarked  \
# 0            892       3    male  34.50000      0      0    7.8292        Q
# 1            893       3  female  47.00000      1      0    7.0000        S
# 2            894       2    male  62.00000      0      0    9.6875        Q
# 3            895       3    male  27.00000      0      0    8.6625        S
# 4            896       3  female  22.00000      1      1   12.2875        S
# ..           ...     ...     ...       ...    ...    ...       ...      ...
# 413         1305       3    male  30.27259      0      0    8.0500        S
# 414         1306       1  female  39.00000      0      0  108.9000        C
# 415         1307       3    male  38.50000      0      0    7.2500        S
# 416         1308       3    male  30.27259      0      0    8.0500        S
# 417         1309       3    male  30.27259      1      1   22.3583        C
#
#      male
# 0       1
# 1       0
# 2       1
# ...

# %%
train=train[['PassengerId','male','Pclass','Age','SibSp','Parch', 'Fare','Embarked','Survived']]

# %%
test=test[['PassengerId','male','Pclass','Age','SibSp','Parch', 'Fare','Embarked']]

# %%
test
# Out:
#      PassengerId  male  Pclass       Age  SibSp  Parch      Fare Embarked
# 0            892     1       3  34.50000      0      0    7.8292        Q
# 1            893     0       3  47.00000      1      0    7.0000        S
# 2            894     1       2  62.00000      0      0    9.6875        Q
# 3            895     1       3  27.00000      0      0    8.6625        S
# 4            896     0       3  22.00000      1      1   12.2875        S
# ..           ...   ...     ...       ...    ...    ...       ...      ...
# 413         1305     1       3  30.27259      0      0    8.0500        S
# 414         1306     0       1  39.00000      0      0  108.9000        C
# 415         1307     1       3  38.50000      0      0    7.2500        S
# 416         1308     1       3  30.27259      0      0    8.0500        S
# 417         1309     1       3  30.27259      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.StandardScaler()
train[["Age","Fare"]]=scaler.fit_transform(train[["Age","Fare"]])
# Out:
# <ipython-input-33-8d31a6a0b826>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[["Age","Fare"]]=scaler.fit_transform(train[["Age","Fare"]])
# C:\Users\Kishore\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
train[["Age","Fare"]]
# Out:
#           Age      Fare
# 0   -0.592481 -0.502445
# 1    0.638789  0.786845
# 2   -0.284663 -0.488854
# 3    0.407926  0.420730
# 4    0.407926 -0.486337
# ..        ...       ...
# 886 -0.207709 -0.386671
# 887 -0.823344 -0.044381
# 888  0.000000 -0.176263
# 889 -0.284663 -0.044381
# 890  0.177063 -0.492378
#
# [891 rows x 2 columns]

# %%
train
# Out:
#      PassengerId  male  Pclass       Age  SibSp  Parch      Fare Embarked  \
# 0              1     1       3 -0.592481      1      0 -0.502445        S
# 1              2     0       1  0.638789      1      0  0.786845        C
# 2              3     0       3 -0.284663      0      0 -0.488854        S
# 3              4     0       1  0.407926      1      0  0.420730        S
# 4              5     1       3  0.407926      0      0 -0.486337        S
# ..           ...   ...     ...       ...    ...    ...       ...      ...
# 886          887     1       2 -0.207709      0      0 -0.386671        S
# 887          888     0       1 -0.823344      0      0 -0.044381        S
# 888          889     0       3  0.000000      1      2 -0.176263        S
# 889          890     1       1 -0.284663      0      0 -0.044381        C
# 890          891     1       3  0.177063      0      0 -0.492378        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# ...

# %%
train=pd.get_dummies(train,columns=["Embarked"])

# %%
test=pd.get_dummies(test,columns=["Embarked"])

# %%
test["Fare"].fillna(test["Fare"].mean(),inplace=True)

# %%
from sklearn import preprocessing 
scaler=preprocessing.StandardScaler()
test[["Age","Fare"]]=scaler.fit_transform(test[["Age","Fare"]])

# %%
target=train["Survived"]
train.drop(["Survived"],axis=1,inplace=True)

# %%
data=pd.concat([train,test])

# %%
len(train)
#train=data[:len(train)]
# Out:
# 891

# %%
test=data[len(test):]
test
# Out:
#      PassengerId  male  Pclass       Age  SibSp  Parch      Fare  Embarked_C  \
# 418          419     1       2  0.023154      0      0 -0.386671           0
# 419          420     0       3 -1.515933      0      2 -0.162169           0
# 420          421     1       3  0.000000      0      0 -0.489442           1
# 421          422     1       3 -0.669435      0      0 -0.492714           0
# 422          423     1       3 -0.053800      0      0 -0.489861           0
# ..           ...   ...     ...       ...    ...    ...       ...         ...
# 413         1305     1       3  0.000000      0      0 -0.494448           0
# 414         1306     0       1  0.691586      0      0  1.313753           1
# 415         1307     1       3  0.651965      0      0 -0.508792           0
# 416         1308     1       3  0.000000      0      0 -0.494448           0
# 417         1309     1       3  0.000000      1      1 -0.237906           1
#
#      Embarked_Q  Embarked_S
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(train,target,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
linear_model=LogisticRegression()
linear_model.fit(x_train,y_train)
# Out:
# C:\Users\Kishore\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=linear_model.predict(x_test)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(pred,y_test)
# Out:
# 0.8145424836601307

# %%
submit=pd.DataFrame({"Survived":pred}).set_index(x_test["PassengerId"])

# %%
submit
# Out:
#              Survived
# PassengerId
# 710                 0
# 440                 0
# 841                 0
# 721                 1
# 40                  1
# ...               ...
# 716                 0
# 526                 0
# 382                 1
# 141                 1
# 174                 0
#
# [295 rows x 1 columns]

# %%
submit.to_csv("submit.csv")

# %%
pd.read_csv("submit.csv")
# Out:
#      PassengerId  Survived
# 0            710         0
# 1            440         0
# 2            841         0
# 3            721         1
# 4             40         1
# ..           ...       ...
# 290          716         0
# 291          526         0
# 292          382         1
# 293          141         1
# 294          174         0
#
# [295 rows x 2 columns]
